# %%
# !pip install -q openai==1.0.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.31.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)

# %%
mobile_app_project = """
Тема: Розробка мобільного застосунку «Розумний будинок».
Мета: Мета дипломної роботи полягає в розробці мобільного застосунку "Розумний Будинок" є створення інтегрованого рішення, яке дозволить користувачам ефективно, зручно та ощадливо керувати всіма пристроями свого дому, що полягає в наданні інтуїтивного інтерфейсу для контролю та моніторингу різних пристроїв і систем.
Завдання:
-	Розробити мобільний застосунок зі зручним та інтуїтивно зрозумілим інтерфейсом для управління пристроями та системами, забезпечивши зручну навігацію та доступ до основних функцій застосунку.
-	Розробити архітектуру системи, що включає мобільний додаток, серверну частину та інтеграцію з пристроями IoT.
-	Провести інтеграцію з хмарними сервісами для інформації про пристрої системи задля збору аналітики, що дозволить керувати будинком ефективніше та ощадливіше.
-	Забезпечити шифрування даних як і клієнта, так і інформації про мешкання та захист від несанкціонованого доступу.
-	Для того, щоб застосунок був не типовим рішенням на ринку, буде розроблено сценарії автоматизації для виконання дій у відповідь на певні події(наприклад, ввімкнення світла різної яскравості, при розпізнаванні обличчя), завдяки інтеграції API та модулів штучного інтелекту  в застосунок.
Предмет:
Технології та методи створення мобільного додатку для управління системами "Розумний Будинок".
Об’єкт:
Система "Розумний Будинок" та її складові компоненти, такі як електротехніка, системи безпеки, камери спостереження та інші пристрої.
Актуальність:
В умовах глобальних змін клімату, зростання цін на енергоносії та зростання рівня злочинності і природних катастроф, питання енергоефективності та безпеки стають все більш актуальними. Застосунок  дозволить не лише оптимізувати споживання енергії та автоматизувати роботу пристроїв, значно знижуючи витрати на комунальні послуги і забезпечуючи економію коштів користувачам, а й завдяки інтеграції API та модулів штучного інтелекту зможе визначити не типову поведінку людини та визвати екстрену службу, що й додає  додатковий рівень безпеки, забезпечуючи спокій та впевненість.
Практичне значення:
Застосунок дозволяє ефективно керувати енергоспоживанням та забезпечує безпеку будинку через інтеграцію з камерами спостереження та датчиками безпеки. Також надає зручність та комфорт користувачам завдяки автоматизації рутинних завдань та можливості віддаленого керування.
"""

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-my-key-kn7iy63byGdeXiyxy5sXT3BlbkFJOCCZTOaP5OZydfIiRbaA")

completion = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[

    {"role": "user", "content": "Сформуй доповідь, відповідно до матеріалів: " + mobile_app_project}
  ]
)
print(completion.choices[0].message.content)
# Out:
# Доповідь на тему: "Розробка мобільного застосунку «Розумний будинок»"
#
# **1. Вступ**
# На сучасному етапі розвитку технологій важко переоцінити роль автоматизації у повсякденному житті. Глобальні зміни клімату, зростання цін на енергоресурси та підвищення кримінальної активності спонукають нас шукати нові шляхи для забезпечення енергоефективності, безпеки та комфорту у домівках. Це і стало основою для розробки мобільного застосунку "Розумний Будинок".
#
# **2. Мета та завдання**
# Мета дипломного проєкту полягає у створенні інтегрованого застосунку, який дозволить користувачам контролювати, моніторити та оптимізувати роботу всіх підключених приладів будинку.
# Завдання, які були поставлені для досягнення цієї мети:
# - Розробка інтуїтивно зрозумілого мобільного інтерфейсу;
# - Створення ефективної архітектури системи, що включає інтеграцію з IoT пристроями;
# - Інтеграція з хмарними сервісами для аналітики;
# - Забезпечення високого рівня безпеки і шифрування даних;
# - Розробка сценаріїв автоматизації з використанням штучного інтелекту.
#
# **3. Актуальність**
# В контексті енергетичної кризи та екологічних викликів, застосунок "Розумний Будинок" є вкрай актуальним. Він сприяє зниженню споживання енергії, оптимізації роботи побутових агрегатів і підвищенню безпеки через автоматизацію і віддалений контроль.
#
# **4. Опис системи**
# Система застосунку базується на модульній архітектурі, що об'єднує мобільний додаток, серверну частину і пристрої IoT. Основні функції включають контроль освітлення, систем опалення, вентиляції та безпеки. Інтеграція з хмарними сервісами дозволяє в реальному часі аналізувати дані та оптимізувати витрати енергії.
#
# **5. Особливості та нововведення**
# Застосунок інтегрує передові технології штучного інтелекту та машинного навчання для автоматизації рутинних завдань і реагування на нестандартні ситуації. Розроблені сценарії автоматизації, такі як автоматичне регулювання освітлення за допомогою розпізнавання осіб або виклик екстрених служб при виявленні підозрілої активності.
#
# **6. Практичне значення**
# Застосунок "Розумний Будинок" не тільки сприяє значному зниженню витрат на комунальні послуги, але й забезпечує вищий рівень безпеки, комфорту та контролю для кінцевих користувачів.
#
# **7. Висновки**
# Розробка мобільного застосунку "Розумний Будинок" відповідає вимогам сучасного ринку і забезпечує користувачів потужним інструментом для керування своїм домашнім простором. Завдяки інтеграції сучасних технологій, застосунок має велике практичне та комерційне значення.
#
# Ця розробка стане в нагоді всім, хто прагне поєднати сучасні технології з повсякденним комфортом і безпекою.
